# %%
import pandas as pd
import numpy as np
import math

# %%
train_x = pd.DataFrame(np.load('train_data.npy'))
train_y = pd.DataFrame(np.load('train_labels.npy'))
test_x = pd.DataFrame(np.load('eval_data.npy'))
test_y = pd.DataFrame(np.load('eval_labels.npy'))

# %%
# 先確認是否有空值
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174461 entries, 0 to 1174460
# Data columns (total 70 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   0       1174461 non-null  float64
#  1   1       1174461 non-null  float64
#  2   2       1174461 non-null  float64
#  3   3       1174461 non-null  float64
#  4   4       1174461 non-null  float64
#  5   5       1174461 non-null  float64
#  6   6       1174461 non-null  float64
#  7   7       1174461 non-null  float64
#  8   8       1174461 non-null  float64
#  9   9       1174461 non-null  float64
#  10  10      1174461 non-null  float64
#  11  11      1174461 non-null  float64
#  12  12      1174461 non-null  float64
#  13  13      1174461 non-null  float64
#  14  14      1174461 non-null  float64
#  15  15      1174461 non-null  float64
#  16  16      1174461 non-null  float64
#  17  17      1174461 non-null  float64
#  18  18      1174461 non-null  float64
#  19  19      1174461 non-null  float64
#  20  20      1174461 non-null  float64
#  21  21      1174461 non-null  float64
#  22  22      1174461 non-null  float64
#  23  23      1174461 non-null  float64
#  24  24      1174461 non-null  float64
#  25  25      1174461 non-null  float64
#  26  26      1174461 non-null  float64
#  27  27      1174461 non-null  float64
#  28  28      1174461 non-null  float64
#  29  29      1174461 non-null  float64
#  30  30      1174461 non-null  float64
#  31  31      1174461 non-null  float64
#  32  32      1174461 non-null  float64
#  33  33      1174461 non-null  float64
#  34  34      1174461 non-null  float64
#  35  35      1174461 non-null  float64
#  36  36      1174461 non-null  float64
#  37  37      1174461 non-null  float64
#  38  38      1174461 non-null  float64
#  39  39      1174461 non-null  float64
#  40  40      1174461 non-null  float64
#  41  41      1174461 non-null  float64
#  42  42      1174461 non-null  float64
#  43  43      1174461 non-null  float64
#  44  44      1174461 non-null  float64
#  45  45      1174461 non-null  float64
#  46  46      1174461 non-null  float64
#  47  47      1174461 non-null  float64
#  48  48      1174461 non-null  float64
#  49  49      1174461 non-null  float64
#  50  50      1174461 non-null  float64
#  51  51      1174461 non-null  float64
#  52  52      1174461 non-null  float64
#  53  53      1174461 non-null  float64
#  54  54      1174461 non-null  float64
#  55  55      1174461 non-null  float64
#  56  56      1174461 non-null  float64
#  57  57      1174461 non-null  float64
#  58  58      1174461 non-null  float64
#  59  59      1174461 non-null  float64
#  60  60      1174461 non-null  float64
#  61  61      1174461 non-null  float64
#  62  62      1174461 non-null  float64
#  63  63      1174461 non-null  float64
#  64  64      1174461 non-null  float64
#  65  65      1174461 non-null  float64
#  66  66      1174461 non-null  float64
#  67  67      1174461 non-null  float64
#  68  68      1174461 non-null  float64
#  69  69      1174461 non-null  float64
# dtypes: float64(70)
# memory usage: 627.2 MB

# %%
test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175302 entries, 0 to 1175301
# Data columns (total 70 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   0       1175302 non-null  float64
#  1   1       1175302 non-null  float64
#  2   2       1175302 non-null  float64
#  3   3       1175302 non-null  float64
#  4   4       1175302 non-null  float64
#  5   5       1175302 non-null  float64
#  6   6       1175302 non-null  float64
#  7   7       1175302 non-null  float64
#  8   8       1175302 non-null  float64
#  9   9       1175302 non-null  float64
#  10  10      1175302 non-null  float64
#  11  11      1175302 non-null  float64
#  12  12      1175302 non-null  float64
#  13  13      1175302 non-null  float64
#  14  14      1175302 non-null  float64
#  15  15      1175302 non-null  float64
#  16  16      1175302 non-null  float64
#  17  17      1175302 non-null  float64
#  18  18      1175302 non-null  float64
#  19  19      1175302 non-null  float64
#  20  20      1175302 non-null  float64
#  21  21      1175302 non-null  float64
#  22  22      1175302 non-null  float64
#  23  23      1175302 non-null  float64
#  24  24      1175302 non-null  float64
#  25  25      1175302 non-null  float64
#  26  26      1175302 non-null  float64
#  27  27      1175302 non-null  float64
#  28  28      1175302 non-null  float64
#  29  29      1175302 non-null  float64
#  30  30      1175302 non-null  float64
#  31  31      1175302 non-null  float64
#  32  32      1175302 non-null  float64
#  33  33      1175302 non-null  float64
#  34  34      1175302 non-null  float64
#  35  35      1175302 non-null  float64
#  36  36      1175302 non-null  float64
#  37  37      1175302 non-null  float64
#  38  38      1175302 non-null  float64
#  39  39      1175302 non-null  float64
#  40  40      1175302 non-null  float64
#  41  41      1175302 non-null  float64
#  42  42      1175302 non-null  float64
#  43  43      1175302 non-null  float64
#  44  44      1175302 non-null  float64
#  45  45      1175302 non-null  float64
#  46  46      1175302 non-null  float64
#  47  47      1175302 non-null  float64
#  48  48      1175302 non-null  float64
#  49  49      1175302 non-null  float64
#  50  50      1175302 non-null  float64
#  51  51      1175302 non-null  float64
#  52  52      1175302 non-null  float64
#  53  53      1175302 non-null  float64
#  54  54      1175302 non-null  float64
#  55  55      1175302 non-null  float64
#  56  56      1175302 non-null  float64
#  57  57      1175302 non-null  float64
#  58  58      1175302 non-null  float64
#  59  59      1175302 non-null  float64
#  60  60      1175302 non-null  float64
#  61  61      1175302 non-null  float64
#  62  62      1175302 non-null  float64
#  63  63      1175302 non-null  float64
#  64  64      1175302 non-null  float64
#  65  65      1175302 non-null  float64
#  66  66      1175302 non-null  float64
#  67  67      1175302 non-null  float64
#  68  68      1175302 non-null  float64
#  69  69      1175302 non-null  float64
# dtypes: float64(70)
# memory usage: 627.7 MB

# %%
view = train_x.describe()
view[24]
# Out:
# count    1.174461e+06
# mean     8.084053e-18
# std      9.999996e-01
# min     -3.557451e+00
# 25%     -8.784684e-01
# 50%     -2.575400e-01
# 75%      9.004684e-01
# max      4.229294e+00
# Name: 24, dtype: float64

# %%
# 觀察 label 分布
import seaborn as sns
sns.countplot(train_y[0])
# Out:
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='0', ylabel='count'>

# %% [markdown]
# ## 簡單使用RFC確認raw data訓練的效果，並當作baseline

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import average_precision_score, precision_score, recall_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import RandomOverSampler
X = train_x[train_x[24]>view[24][1]].reset_index(drop = True)
Y = train_y[train_x[24]>view[24][1]].reset_index(drop = True)

test_ratio = 0.3
X_train = X [math.ceil(len(X)*test_ratio) :]
X_test = X [ : math.ceil(len(X)*test_ratio)]

y_train = Y[math.ceil(len(X)*test_ratio) :]
y_test = Y[ : math.ceil(len(X)*test_ratio)]

ros = RandomOverSampler(random_state = 40)
X_train, y_train = ros.fit_resample(X_train, y_train)

model = RandomForestClassifier(n_estimators=50, max_depth=5,random_state=42)

model.fit(X_train,y_train)
y_test_pred = model.predict(X_test)

y_train_pred = model.predict(X_train)
precision, recall, f1, _ = score(y_test, y_test_pred)
print ( "precision(0, 1, 2):" ,precision )    
print ( "recall score(0, 1, 2):" ,recall )
Y_train_pre = model.predict(X_train)
print('training score :' , accuracy_score(y_train, Y_train_pre))
print('testing score :' , accuracy_score(y_test, y_test_pred))
# Out:
# C:\Users\kevin\AppData\Local\Temp/ipykernel_20356/3499109776.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train,y_train)
# precision(0, 1, 2): [0.65694203 0.50795659 0.09769115]
# recall score(0, 1, 2): [0.49568449 0.62177369 0.98826291]
# training score : 0.7025186345392759
# testing score : 0.551522316777675

# %%
confusion_matrix(y_train, Y_train_pre)
# Out:
# array([[ 91217, 115408,   7896],
#        [ 60767, 148827,   4927],
#        [   867,   1583, 212071]], dtype=int64)

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[48414, 43562,  5695],
#        [25277, 44976,  2082],
#        [    5,     5,   842]], dtype=int64)

# %%
from matplotlib import pyplot as plt
def f_importances(coef, names):
    imp = coef
    imp,names = zip(*sorted(zip(imp,names)))
    plt.barh(range(len(names)), imp, align='center')
    plt.yticks(range(len(names)), names)
    plt.show()

f_importances(model.feature_importances_, train_x.columns)

# %%
normalized_df=(train_x-train_x.mean())/train_x.std()

# %%
from sklearn.decomposition import FactorAnalysis
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

X_reduced = PCA(n_components = 3).fit_transform(normalized_df.values)

col = ['red','yellow','forestgreen']

fig = plt.figure()
ax = fig.add_subplot(111,projection ='3d')

#X_reduced = X_reduced [0:1476]

# add zaxis for the third dimension.
for y , color in zip([0,1,2], col):
    xs = X_reduced[train_y[0] == y].T[0]
    ys = X_reduced[train_y[0] == y].T[1]
    zs = X_reduced[train_y[0] == y].T[2]
    ax.scatter(xs, ys, zs, c = color,  marker='o')

ax.view_init(30, 60)
ax.grid(color='gray', linestyle=':', linewidth=2, alpha=0.2)
ax.set_xlabel('\nX Label')
ax.set_ylabel('\nY Label')
ax.set_zlabel('\nZ Label')
plt.show()

# %%
np.array(model.feature_importances_)
# Out:
# array([1.08110206e-02, 8.34358950e-03, 6.41006656e-02, 4.01882748e-02,
#        2.27809505e-03, 1.55445712e-03, 4.02671694e-03, 1.51292060e-03,
#        1.35723847e-05, 1.16564857e-02, 8.05477164e-05, 1.32990528e-05,
#        7.42809451e-03, 5.82273631e-03, 1.87084727e-02, 1.51732226e-03,
#        1.13759633e-02, 1.11647767e-02, 2.84688354e-02, 4.37887976e-04,
#        1.06861265e-04, 2.15977974e-02, 3.49955789e-03, 5.90333105e-05,
#        1.58291686e-01, 9.91481996e-05, 2.79272808e-03, 1.33252870e-03,
#        5.57604497e-04, 1.83068994e-04, 1.10774399e-03, 1.45495456e-04,
#        1.49444370e-03, 3.90556216e-07, 2.24399631e-03, 5.21571529e-04,
#        4.83953412e-04, 4.98449356e-04, 1.21160026e-04, 3.90116475e-04,
#        5.70768012e-04, 1.30542625e-03, 3.70621016e-05, 1.70025509e-03,
#        1.16994692e-04, 3.20486924e-03, 6.08962654e-03, 5.24763379e-03,
#        1.01735035e-03, 2.31594509e-01, 2.14273167e-04, 1.55956833e-04,
#        1.66263143e-03, 1.48076063e-02, 6.50562742e-02, 5.54884841e-02,
#        8.55335764e-03, 3.26262941e-02, 1.65144966e-02, 1.77352317e-02,
#        3.15630456e-03, 1.41397737e-02, 2.64996920e-02, 6.74535779e-03,
#        1.26753803e-02, 1.09676142e-02, 6.21959075e-04, 1.59060759e-02,
#        1.98786439e-02, 6.79027844e-04])

# %%
model.feature_importances_[49]
# Out:
# 0.23159450865208403

# %%
view[49]
# Out:
# count    1.174461e+06
# mean    -1.659836e-17
# std      9.999996e-01
# min     -1.830028e+01
# 25%     -7.123657e-01
# 50%     -6.828219e-02
# 75%      4.894603e-01
# max      6.572048e+01
# Name: 49, dtype: float64

# %%
cross = train_x[24]*train_x[49]

# %%
sum(cross) / len(cross)
# Out:
# 0.6724378699669215

# %%
train_y[corss>(sum(cross) / len(cross))].value_counts()
# Out:
# 0    237134
# 2    122260
# 1    105150
# dtype: int64

# %%
filter21x = train_x[train_x[24]>view[24][1]]
filter21y = train_y[train_x[24]>view[24][1]]

# %%
filter21y.value_counts()
# Out:
# 0    312192
# 1    254512
# 2      2822
# dtype: int64

# %%
filter21y[filter21x[49]>view[49][6]].value_counts()
# Out:
# 0    151111
# 1    132003
# 2       260
# dtype: int64

# %%
drop_label = X.columns[model.feature_importances_ < 0.01]

# %%
X_refator = train_x.drop(columns=drop_label, axis = 1)

# %%
X_refator['cross']= train_x[24]*train_x[49]
X_refator['inter']= train_x[24]/(train_x[49]- min(train_x[49] +1 ))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import average_precision_score, precision_score, recall_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import RandomOverSampler
X = X_refator[X_refator[24]>view[24][1]].reset_index(drop = True)
Y = train_y[X_refator[24]>view[24][1]].reset_index(drop = True)

test_ratio = 0.3
X_train = X [math.ceil(len(X)*test_ratio) :]
X_test = X [ : math.ceil(len(X)*test_ratio)]

y_train = Y[math.ceil(len(X)*test_ratio) :]
y_test = Y[ : math.ceil(len(X)*test_ratio)]

ros = RandomOverSampler(random_state = 40)
X_train, y_train = ros.fit_resample(X_train, y_train)

model = RandomForestClassifier(n_estimators=50, max_depth=5,random_state=42)

model.fit(X_train,y_train)
y_test_pred = model.predict(X_test)

y_train_pred = model.predict(X_train)
precision, recall, f1, _ = score(y_test, y_test_pred)
print ( "precision(0, 1, 2):" ,precision )    
print ( "recall score(0, 1, 2):" ,recall )
Y_train_pre = model.predict(X_train)
print('training score :' , accuracy_score(y_train, Y_train_pre))
print('testing score :' , accuracy_score(y_test, y_test_pred))
# Out:
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\kevin\AppData\Local\Temp/ipykernel_20356/3394454940.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train,y_train)
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# precision(0, 1, 2): [0.62654794 0.51402569 0.0834833 ]
# recall score(0, 1, 2): [0.58639719 0.49348172 0.98004695]
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# training score : 0.6932064149119822
# testing score : 0.5490231654356249

# %%
confusion_matrix(y_train, Y_train_pre)
# Out:
# array([[114267,  91144,   9110],
#        [ 87427, 121460,   5634],
#        [  2399,   1727, 210395]], dtype=int64)

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[57274, 33744,  6653],
#        [34125, 35696,  2514],
#        [   13,     4,   835]], dtype=int64)

# %%
from matplotlib import pyplot as plt
def f_importances(coef, names):
    imp = coef
    imp,names = zip(*sorted(zip(imp,names)))
    plt.barh(range(len(names)), imp, align='center')
    plt.yticks(range(len(names)), names)
    plt.show()

f_importances(model.feature_importances_, X_refator.columns)

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import average_precision_score, precision_score, recall_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import RandomOverSampler
X = X_refator[X_refator[24]>view[24][1]].reset_index(drop = True)
Y = train_y[X_refator[24]>view[24][1]].reset_index(drop = True)

test_ratio = 0.3
X_train = X [math.ceil(len(X)*test_ratio) :]
X_test = X [ : math.ceil(len(X)*test_ratio)]

y_train = Y[math.ceil(len(X)*test_ratio) :]
y_test = Y[ : math.ceil(len(X)*test_ratio)]

ros = RandomOverSampler(random_state = 40)
X_train, y_train = ros.fit_resample(X_train, y_train)

model = XGBClassifier( booster='gbtree', max_depth=5,                
                  n_estimators=100, n_jobs=4, nthread=-1, eval_metric='mlogloss',
                  random_state=27,  tree_method='exact',
                  validate_parameters=1, verbosity=None)

model.fit(X_train,y_train)
y_test_pred = model.predict(X_test)

y_train_pred = model.predict(X_train)
precision, recall, f1, _ = score(y_test, y_test_pred)
print ( "precision(0, 1, 2):" ,precision )    
print ( "recall score(0, 1, 2):" ,recall )
Y_train_pre = model.predict(X_train)
print('training score :' , accuracy_score(y_train, Y_train_pre))
print('testing score :' , accuracy_score(y_test, y_test_pred))
# Out:
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\kevin\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# precision(0, 1, 2): [0.64664141 0.54425474 0.30734323]
# recall score(0, 1, 2): [0.67268688 0.50282712 0.87441315]
# training score : 0.7435728902997841
# testing score : 0.6017804258507065

# %%
confusion_matrix(y_train, Y_train_pre)
# Out:
# array([[128256,  84148,   2117],
#        [ 78400, 135759,    362],
#        [     0,      0, 214521]], dtype=int64)

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[65702, 30446,  1523],
#        [35807, 36372,   156],
#        [   96,    11,   745]], dtype=int64)

# %%
from matplotlib import pyplot as plt
def f_importances(coef, names):
    imp = coef
    imp,names = zip(*sorted(zip(imp,names)))
    plt.barh(range(len(names)), imp, align='center')
    plt.yticks(range(len(names)), names)
    plt.show()

f_importances(model.feature_importances_, X_refator.columns)

# %%
X_reduced
# Out:
# array([[-1.05740817,  0.96500758],
#        [-1.29721839, -0.59009512],
#        [-0.96690995, -0.30408545],
#        ...,
#        [-0.94172684, -2.01975162],
#        [-0.81818934, -2.10402368],
#        [ 1.26814334, -0.2869734 ]])

# %%
normalized_df=(X_refator-X_refator.mean())/X_refator.std()

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

X_reduced = LinearDiscriminantAnalysis().fit(normalized_df.values, y= train_y).transform(normalized_df.values)

col = ['red','yellow','forestgreen']

fig = plt.figure()
ax = fig.add_subplot(111,projection ='3d')

#X_reduced = X_reduced [0:1476]

# add zaxis for the third dimension.
for y , color in zip([0,1,2], col):
    xs = X_reduced[train_y[0] == y].T[0]
    ys = X_reduced[train_y[0] == y].T[1]
#     zs = X_reduced[train_y[0] == y].T[2]
    ax.scatter(xs, ys, zs, c = color,  marker='o')

ax.view_init(30, 60)
ax.grid(color='gray', linestyle=':', linewidth=2, alpha=0.2)
ax.set_xlabel('\nX Label')
ax.set_ylabel('\nY Label')
ax.set_zlabel('\nZ Label')
plt.show()
# Out:
# C:\Users\kevin\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20356/2631676999.py in <module>
#       3 from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#       4
# ----> 5 X_reduced = LinearDiscriminantAnalysis(n_components=3).fit(normalized_df.values, y= train_y).transform(normalized_df.values)
#       6
#       7 col = ['red','yellow','forestgreen']
#
# ~\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py in fit(self, X, y)
#     574         else:
#     575             if self.n_components > max_components:
# --> 576                 raise ValueError(
#     577                     "n_components cannot be larger than min(n_features, n_classes - 1)."
#     578                 )
#
# ValueError: n_components cannot be larger than min(n_features, n_classes - 1).
